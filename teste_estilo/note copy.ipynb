# %% [markdown]
# Este é um texto normal, mas
#
# :::marker
# esta frase está marcada como marcador
# :::
#
# e o texto continua normalmente.

# %% [markdown]
# Este é um texto normal, mas
#
# ==esta frase está marcada como marcador==
#
# e o texto continua normalmente.

# %% [markdown]
# from pathlib import Path
# from IPython.display import HTML
# HTML("<style>" + Path("theme.css").read_text(encoding="utf-8") + "</style>")

# %%
import re
from IPython.display import HTML, display

def render_markers(md):
    html = re.sub(r'==(.+?)==', r'<abobora>\1</abobora>', md)
    display(HTML(html))
# Out:
# The kernel failed to start as the Python Environment '.venv (Python 3.12.12)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %% [markdown]
# Este é um texto normal, mas <abobora>marcador</abobora> e o texto continua normalmente.

# %% [markdown]
# render_markers("""
# Este é um texto normal, mas ==esta frase está marcada como marcador== e o texto continua.
#
# - e isso aqui é lista
# - e **isso** é negrito
# """)

# %% [markdown]
# ==esta frase está marcada==

# %% [markdown]
# <div class="idea">
# Talvez a hidrodinâmica esteja codificando coarse-graining temporal.
# </div>

# %% [markdown]
# Este é um texto normal, mas
# <span class="marker">esta frase está marcada como marcador</span>
# e o texto continua normalmente.

# %% [markdown]
# asdfaskfj

# %% [markdown]
# Este é um texto normal, mas
# <span class="marker">esta frase está marcada como marcador</span>
# e o texto continua normalmente.

# %% [markdown]
# Este é um texto normal, mas <mark>marcador</mark> e o texto continua normalmente.

# %% [markdown]
# uma celula

# %% [markdown]
# outra celula

# %% [markdown]
# Este é um texto normal, mas <mark>marcador</mark> e o texto continua normalmente.

# %% [markdown]
# Este é um texto normal, mas <mark>marcador</mark> e o texto continua normalmente.
