# %% [markdown]
# <details>
#   <summary style="text-align:center; font-size:1.1em;">
#
#   $$
#   \mathrm{Var}(X)=\mathbb{E}[X^2]-\mathbb{E}[X]^2
#   $$
#
#   </summary>
#
#   <div>
#
#   **Prova.**
#
#   **Passo 1.** Expanda:
#   $$
#   (X-\mu)^2 = X^2 - 2\mu X + \mu^2
#   $$
#
#   **Passo 2.** Aplique linearidade da esperança:
#   $$
#   \mathbb{E}[(X-\mu)^2]
#   = \mathbb{E}[X^2] - 2\mu\,\mathbb{E}[X] + \mu^2
#   $$
#
#   **Passo 3.** Use $\mu=\mathbb{E}[X]$:
#   $$
#   \mathbb{E}[X^2] - \mu^2
#   $$
#
#   \(\square\)
#
#   </div>
# </details>
